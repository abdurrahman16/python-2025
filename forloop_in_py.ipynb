# %% [markdown]
# <a href="https://colab.research.google.com/github/abdurrahman16/python-2025/blob/main/forloop_in_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
checlist=[1,5,7,9,10]
#for lp in checlist:
    #print(lp)

    #ANOTHER STYLE
for new in range(5,1001):
           print(f'Nasa is hacked: {new}%')
# Out:
# Nasa is hacked: 5%
# Nasa is hacked: 6%
# Nasa is hacked: 7%
# Nasa is hacked: 8%
# Nasa is hacked: 9%
# Nasa is hacked: 10%
# Nasa is hacked: 11%
# Nasa is hacked: 12%
# Nasa is hacked: 13%
# Nasa is hacked: 14%
# Nasa is hacked: 15%
# Nasa is hacked: 16%
# Nasa is hacked: 17%
# Nasa is hacked: 18%
# Nasa is hacked: 19%
# Nasa is hacked: 20%
# Nasa is hacked: 21%
# Nasa is hacked: 22%
# Nasa is hacked: 23%
# Nasa is hacked: 24%
# Nasa is hacked: 25%
# Nasa is hacked: 26%
# Nasa is hacked: 27%
# Nasa is hacked: 28%
# Nasa is hacked: 29%
# Nasa is hacked: 30%
# Nasa is hacked: 31%
# Nasa is hacked: 32%
# Nasa is hacked: 33%
# Nasa is hacked: 34%
# Nasa is hacked: 35%
# Nasa is hacked: 36%
# Nasa is hacked: 37%
# Nasa is hacked: 38%
# Nasa is hacked: 39%
# Nasa is hacked: 40%
# Nasa is hacked: 41%
# Nasa is hacked: 42%
# Nasa is hacked: 43%
# Nasa is hacked: 44%
# Nasa is hacked: 45%
# Nasa is hacked: 46%
# Nasa is hacked: 47%
# Nasa is hacked: 48%
# Nasa is hacked: 49%
# ...
